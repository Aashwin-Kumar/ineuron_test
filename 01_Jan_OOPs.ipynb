# %% [raw]
# Q 1. What is the primary goal of Object-Oriented Programming (OOP)?
#
# Ans: First understand what is OOPs? its a programming paradigm(set of rules) based on the idea or concept called "object".
#
# - this object contains data and functions/methods to manipulate that data.
#
# - why we need oops? so to organise our code in a way that it will easy to maintain and understand,it makes thing easy.
#
# - primary goal of OOPs? again the main objective is to organise our code in a way that it will easy to maintain and understand and Through concepts like encapsulation, inheritance, and polymorphism, OOP facilitates the creation of modular and scalable software, making it easier to understand, modify, and expand codebases.

# %% [raw]
# Q 2. What is an object in Python?
#
# Ans: What is Object? an object its simply a collection of a data(variable) and methods/functions.Everything in Python is considered an object, including data types, functions, and modules.
#
# Defination: an object is called intance of a class, i.e suppose bike is a class then we can create object/instance of that class like, bike1,bike2,bike3 and so on.
#
# Syantax of creating on object:
# object_name = Classname()

# %% [raw]
# What is a class in Python?
#
# Ans: Class provide a way to bind data and functionality togather.
# - its defines as a blueprint or a templet for a creating an object.
# - we use class keyword to create it.
# Syntax of class:
#
# class Classname:
#     def __init__(self,para1,para2..):
#     self.para1 = value
#
#     def methodname(self,paras)
#     methods..
#
#     pass

# %% [raw]
# Q 4. What are attributes and methods in a class?
#
# Ans:Attribute are like or is variables that holds the values, they are properties of object created from that class.
#
# - attributes are defined within a calss and assosiated with the objects of the class.
# - each attribute/object has its own set of attributes.
# - we can access attributes by simply using dot notations (object.attribute)
# i.e :
# class Cat:
#     def __init__(self,name,food)
#     self.name = name #attribute
#     self.food = food #attribute
#
# Method:
# - is nothing but a functions which is written inside of a class, and methods which are written outside we normally call it a function.
# - and another bigdiffrence i study is how you call it? ex: len(l1) here len is function and l1.append(9) here append is also a function thats weird, so we can say though they are functions but whats makes method is how you call it inside class.
#
# class Cat:
#     def__init__(self,name,food):
#     self.name = name
#     self.food = food
#
#     def Hunt(self) # this is called method
#     print("she is a good prediator")

# %% [raw]
# Q 5. What is the difference between class variables and instance variables in Python?
#
# Ans: both are types of attributes but diffrent definations and purposes.
#
# - Class Varibale:
# -this are accessible to all instances/objects in class.
# - its value remain the same for every object.
# -class variable defined outside of __init__.
#
# Ex: class Cat:
#     category = "Cat Family" # this is class variable
#
#     def__init__(self,name,food):
#     self.name = name
#     self.food = food
#
#
# - Instance Variable:
# - this varible define inside the __init__(constructor) method.
# - this variable specify to each object of class
# - they are associated with keyword called "self"
# - this are dynamic because they might have diffrent values for diffrent objets.
#
# Ex: class Cat:
#     category = "Cat Family" # this is class variable
#
#     def__init__(self,name,food):
#     # Instance variables
#     self.name = name
#     self.food = food

# %% [raw]
# Q 6. What is the purpose of the self parameter in Python class methods?
#
# Ans: What is Self?
# - Its a keyword, and it define as whichever object you are woring on/working with that is the 'self'.
# - in short self = object let me explain:
# class Animal:
#     def __init__(self,name):
#      self.name = name
#      print(id(self))
#
# dog = Animal("Ranvir")
# print(id(dog))
#
# in above small snippet in output you will get id of self is : 2193318386896 .
# and id for dog object is : 2193318386896, that means both are same hence in python self is = object.
#
# -in class method you have to give a one parameter(self) otherwise it will through an error:
# takes o arguments but 1 was give.
# how? when we use . notation on object so our default input will be that object.

# %%
class Book:
    def __init__(self,title, author, isbn, publication_year,available_copies):
        self.author = author
        self.isbn = isbn
        self.publication_year = publication_year
        self.available_copies = available_copies
        self.title = title

    def check_out(self):
        if self.available_copies > 0:
            self.available_copies -= 1
            print(f"Thanks for Choosing {self.title}, Happy Reading!")
        else:
            print(f"Sorry Currently There is {self.available_copies} copies available.")

    def return_book(self):
        self.available_copies += 1
        print(f"Thanks For Selecting {self.title} Vsist Again!")

    def display_book_info(self):
        print(self.title)
        print(self.author)
        print(self.isbn)
        print(self.isbn)
        print(self.publication_year)
        print(self.available_copies)

Book1 = Book("ikigai", " Hector Garcia", 1234567362728, 2009,3)
# Book1.return_book() # returning a book
Book1.check_out()  # renting a book

# Book1.display_book_info()  # Display book information
# Out:
# Thanks for Choosing ikigai, Happy Reading!

# %%
class Ticket:
    def __init__(self,ticket_id,event_name,event_date,venue,seat_number,price):
        self.ticket_id = ticket_id
        self.event_name = event_name
        self.event_date = event_date
        self.venue = venue
        self.seat_number = seat_number
        self.price = price
        self.is_reserved = False

    def reserve_ticket(self):
        if not self.is_reserved:
            self.is_reserved = True
            print(f"ticket no. {self.ticket_id} and seat no: {self.seat_number} for {self.event_date} is reserved for event {self.event_name} successfuly")
        else:
            print("ticket booked already")

    def cancel_reservation(self):
        if self.is_reserved:
            self.is_reserved = False
            print(f"Your ticket for {self.event_name} ticket no: {self.ticket_id} is canceled successfuly")

        else:
            print("Book Your ticket, we see no reservetion")

    def display_ticket_info(self):
        print("Ticket Information:")
        print("Venue Ticket No: ",self.ticket_id)
        print("Venue Name: ",self.event_name)
        print("Venue Date: ",self.event_date)
        print("Venue: ",self.venue)
        print("Seat No: ",self.seat_number)
        print("₹",self.price)

new_ticket = Ticket(121212317, "Sundance", "20 Jan", "goa", 12, 2311)

# new_ticket.display_ticket_info()
new_ticket.reserve_ticket()
new_ticket.cancel_reservation()
# Out:
# ticket no. 121212317 and seat no: 12 for 20 Jan is reserved for event Sundance successfuly
# Your ticket for Sundance ticket no: 121212317 is canceled successfuly

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)
        print(f'Congratulations your item: {item} added to the cart')

    def remove_item(self, item):
        if len(self.items) == 0:
             print("Your cart is empty already")
        else:
            self.items.remove(item)
            print(f'you have successfuly remove {item} from your cart')


    def view_cart(self):
        print("Your Cart is: ",self.items)

    def clear_cart(self):
        if len(self.items) == 0:
             print("Your cart is empty already")
        else:
            self.items.remove()



my_cart = ShoppingCart()

my_cart.add_item("Tv")
my_cart.view_cart()
my_cart.remove_item("Tv")
# Out:
# Congratulations your item: Tv added to the cart
# Your Cart is:  ['Tv']
# you have successfuly remove Tv from your cart

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)
        print(f'Congratulations your item: {item} added to the cart')

    def remove_item(self, item):
        if len(self.items) == 0:
             print("Your cart is empty already")
        elif item not in self.items:
            print(f'Error: The item "{item}" is not in your cart.')
        else:
            self.items.remove(item)
            print(f'You have successfully removed "{item}" from your cart.')

    def view_cart(self):
        print("Your Cart is: ",self.items)

    def clear_cart(self):
        if len(self.items) == 0:
             print("Your cart is empty already")
        else:
            self.items.remove()



my_cart = ShoppingCart()


my_cart.add_item("Tv")
my_cart.add_item("Laptop")
my_cart.add_item("Phone")
my_cart.view_cart()
my_cart.remove_item("Tv")
# Out:
# Congratulations your item: Tv added to the cart
# Congratulations your item: Laptop added to the cart
# Congratulations your item: Phone added to the cart
# Your Cart is:  ['Tv', 'Laptop', 'Phone']
# You have successfully removed "Tv" from your cart.

# %%
class Student:
    def __init__(self, name, age, grade, student_id):
        self. name = name
        self.age = age
        self.grade = grade
        self.student_id =student_id
        self. attendance = {}

    def update_attendance(self, date, status):
       self.attendance[date] = status
       print(f"Attendance for {self.name} on {date}: {status}")

    def get_attendance(self):
        return self.attendance

    def get_average_attendance(self):
        if not self.attendance:
            return 0

        total_days = len(self.attendance)
        present_days = sum(status == 'present' for status in self.attendance.values())
        average_percentage = (present_days / total_days) * 100
        return round(average_percentage, 2)

student1 = Student("Ashwin", 27, "X", 21)
student2 = Student("Sam", 27, "X", 21)
student3 = Student("Chris", 27, "X", 21)




results = student3.get_attendance()
student3.update_attendance("2024-01-23", "present")
results2 = student3.get_average_attendance()


print(results2)
# Out:
# Attendance for Chris on 2024-01-23: present
# 100.0
